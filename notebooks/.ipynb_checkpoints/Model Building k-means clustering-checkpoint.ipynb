# %%
import os
import sys

# %%
os.environ["PYSPARK_PYTHON"]="C:\Spark\spark-3.3.2-bin-hadoop2\python"
os.environ["JAVA_HOME"] = "C:\Program Files\Java\jdk-18.0.2.1"
os.environ["SPARK_HOME"] = "C:\Spark\spark-3.3.2-bin-hadoop2"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
sys.path.insert(0, os.environ["PYLIB"] + "/py4j-0.10.9.5-src.zip")
sys.path.insert(0, os.environ["PYLIB"] + "/pyspark.zip")

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("r_model").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-0OH3S55:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>r_model</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# importing pandas
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
cluster_data = spark.read.option("header","true").csv("../data/EDA/clustering_data.csv")
cluster_data.printSchema()
cluster_data = cluster_data.drop("_c0")
cluster_data.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- subject_id: string (nullable = true)
#  |-- hadm_id: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)
#
# root
#  |-- subject_id: string (nullable = true)
#  |-- hadm_id: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)

# %%
predict_data = spark.read.option("header","true").csv("../data/EDA/prediction_value.csv")
predict_data.printSchema()
predict_data = predict_data.drop("_c0")
predict_data.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- subject_id: string (nullable = true)
#  |-- charlson_comorbidity_index: string (nullable = true)
#
# root
#  |-- subject_id: string (nullable = true)
#  |-- charlson_comorbidity_index: string (nullable = true)

# %%
# remove subject_id and hadm_id columns
cluster_data = cluster_data.drop("subject_id","hadm_id")
predict_data = predict_data.drop("subject_id")

# %%
print(cluster_data.count())
print(predict_data.count())
# Out:
# 100
# 100

# %%
# convert all values to double
import pyspark.sql.functions as F
print(cluster_data.printSchema())
numeric_cols = cluster_data.columns
numeric_cols.remove("gender")
cluster_data = cluster_data.select(*(F.round(F.col(c).cast("double"), 2).alias(c) for c in numeric_cols), "gender")
print(cluster_data.printSchema())
# Out:
# root
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)
#
# None
# root
#  |-- age: double (nullable = true)
#  |-- db_wbc: double (nullable = true)
#  |-- basophils_abs: double (nullable = true)
#  |-- eosinophils_abs: double (nullable = true)
#  |-- lymphocytes_abs: double (nullable = true)
#  |-- monocytes_abs: double (nullable = true)
#  |-- neutrophils_abs: double (nullable = true)
#  |-- basophils: double (nullable = true)
#  |-- eosinophils: double (nullable = true)
#  |-- lymphocytes: double (nullable = true)
#  |-- monocytes: double (nullable = true)
#  |-- neutrophils: double (nullable = true)
#  |-- aniongap: double (nullable = true)
#  |-- bicarbonate: double (nullable = true)
#  |-- bun: double (nullable = true)
#  |-- calcium: double (nullable = true)
#  |-- chloride: double (nullable = true)
#  |-- creatinine: double (nullable = true)
#  |-- glucose: double (nullable = true)
#  |-- sodium: double (nullable = true)
#  |-- potassium: double (nullable = true)
#  |-- inr: double (nullable = true)
#  |-- pt: double (nullable = true)
#  |-- ptt: double (nullable = true)
#  |-- hematocrit: double (nullable = true)
#  |-- hemoglobin: double (nullable = true)
#  |-- mch: double (nullable = true)
#  |-- mchc: double (nullable = true)
#  |-- mcv: double (nullable = true)
#  |-- platelet: double (nullable = true)
#  |-- rbc: double (nullable = true)
#  |-- rdw: double (nullable = true)
#  |-- wbc: double (nullable = true)
#  |-- scr_min: double (nullable = true)
#  |-- ckd: double (nullable = true)
#  |-- mdrd_est: double (nullable = true)
#  |-- scr_baseline: double (nullable = true)
#  |-- alt: double (nullable = true)
#  |-- alp: double (nullable = true)
#  |-- ast: double (nullable = true)
#  |-- bilirubin_total: double (nullable = true)
#  |-- gender: string (nullable = true)
#
# None

# %%
numeric_cols.remove("age") # do not impute age and gender. They are expected to be present

# %%
# fill the missing values with the median value
from pyspark.ml.feature import Imputer


print (cluster_data.describe().toPandas())
imputer = Imputer(
    inputCols = numeric_cols, 
    outputCols = ["{}_imputed".format(c) for c in numeric_cols]
    ).setStrategy("median")

# Add imputation cols to df
cluster_data = imputer.fit(cluster_data).transform(cluster_data)
print (cluster_data.describe().toPandas())
# Out:
#   summary                 age             db_wbc        basophils_abs  \
# 0   count                 100                100                   63
# 1    mean  62.360399999999984              14.49  0.06063492063492061
# 2  stddev  16.093590537976304  8.628745709849868  0.06229153662476343
# 3     min               21.16                2.4                  0.0
# 4     max               91.77               62.4                 0.26
#
#        eosinophils_abs    lymphocytes_abs       monocytes_abs  \
# 0                   63                 63                  63
# 1  0.23873015873015868  3.034444444444444  0.9249206349206349
# 2  0.31759932184605055  7.104795013677731  0.6162919108718221
# 3                  0.0               0.25                0.26
# 4                  1.9              57.41                3.84
#
#       neutrophils_abs           basophils         eosinophils  ...  \
# 0                  63                  63                  63  ...
# 1   12.62555555555556   0.465079365079365   1.992063492063492  ...
# 2  7.8910330444727315  0.5806444501332619  2.7609781802891473  ...
# 3                2.73                 0.0                 0.0  ...
# 4                40.8                 4.0                18.0  ...
#
#           rdw_imputed        wbc_imputed     scr_min_imputed  \
# 0                 100                100                 100
# 1  14.894999999999998              14.49  0.9280000000000005
# 2  2.3226758775867187  8.628745709849868   0.877102668396973
# 3                12.0                2.4                 0.1
# 4                29.3               62.4                 6.0
#
#            ckd_imputed     mdrd_est_imputed scr_baseline_imputed  \
# 0                  100                  100                  100
# 1                 0.17   0.9653000000000003   0.9094000000000004
# 2  0.37752516806863695  0.12674204296343597   0.8670614718459101
# 3                  0.0                 0.77                  0.1
# 4                  1.0                 1.22                  6.0
#
#          alt_imputed        alp_imputed         ast_imputed  \
# 0                100                100                 100
# 1             170.77             113.57              308.39
# 2  820.4818349696424  63.82065385583149  1451.4308502406523
# 3                7.0               32.0                 5.0
# 4             8010.0              414.0             13060.0
#
#   bilirubin_total_imputed
# 0                     100
# 1      1.5859999999999994
# 2       4.382334141214305
# 3                     0.2
# 4                    35.9
#
# [5 rows x 83 columns]
#   summary                 age             db_wbc        basophils_abs  \
# 0   count                 100                100                   63
# 1    mean  62.360399999999984              14.49  0.06063492063492061
# 2  stddev  16.093590537976304  8.628745709849868  0.06229153662476343
# 3     min               21.16                2.4                  0.0
# 4     max               91.77               62.4                 0.26
#
#        eosinophils_abs    lymphocytes_abs       monocytes_abs  \
# 0                   63                 63                  63
# 1  0.23873015873015868  3.034444444444444  0.9249206349206349
# 2  0.31759932184605055  7.104795013677731  0.6162919108718221
# 3                  0.0               0.25                0.26
# 4                  1.9              57.41                3.84
#
#       neutrophils_abs           basophils         eosinophils  ...  \
# 0                  63                  63                  63  ...
# 1   12.62555555555556   0.465079365079365   1.992063492063492  ...
# 2  7.8910330444727315  0.5806444501332619  2.7609781802891473  ...
# 3                2.73                 0.0                 0.0  ...
# 4                40.8                 4.0                18.0  ...
#
#           rdw_imputed        wbc_imputed     scr_min_imputed  \
# 0                 100                100                 100
# 1  14.894999999999998              14.49  0.9280000000000005
# 2  2.3226758775867187  8.628745709849868   0.877102668396973
# 3                12.0                2.4                 0.1
# 4                29.3               62.4                 6.0
#
#            ckd_imputed     mdrd_est_imputed scr_baseline_imputed  \
# 0                  100                  100                  100
# 1                 0.17   0.9653000000000003   0.9094000000000004
# 2  0.37752516806863695  0.12674204296343597   0.8670614718459101
# 3                  0.0                 0.77                  0.1
# 4                  1.0                 1.22                  6.0
#
#          alt_imputed        alp_imputed         ast_imputed  \
# 0                100                100                 100
# 1             170.77             113.57              308.39
# 2  820.4818349696424  63.82065385583149  1451.4308502406523
# 3                7.0               32.0                 5.0
# 4             8010.0              414.0             13060.0
#
#   bilirubin_total_imputed
# 0                     100
# 1      1.5859999999999994
# 2       4.382334141214305
# 3                     0.2
# 4                    35.9
#
# [5 rows x 83 columns]

# %%
cluster_data.describe().toPandas()
# Out:
#   summary                 age             db_wbc        basophils_abs  \
# 0   count                 100                100                   63
# 1    mean  62.360399999999984              14.49  0.06063492063492061
# 2  stddev  16.093590537976304  8.628745709849868  0.06229153662476343
# 3     min               21.16                2.4                  0.0
# 4     max               91.77               62.4                 0.26
#
#        eosinophils_abs    lymphocytes_abs       monocytes_abs  \
# 0                   63                 63                  63
# 1  0.23873015873015868  3.034444444444444  0.9249206349206349
# 2  0.31759932184605055  7.104795013677731  0.6162919108718221
# 3                  0.0               0.25                0.26
# 4                  1.9              57.41                3.84
#
#       neutrophils_abs           basophils         eosinophils  \
# 0                  63                  63                  63
# 1   12.62555555555556   0.465079365079365   1.992063492063492
# 2  7.8910330444727315  0.5806444501332619  2.7609781802891473
# 3                2.73                 0.0                 0.0
# 4                40.8                 4.0                18.0
#
#           lymphocytes          monocytes         neutrophils  \
# 0                  63                 63                  63
# 1  18.463492063492065  6.487301587301589   78.88730158730162
# 2  17.119619960992328   3.29929083599511  13.898485552952975
# 3                 2.0                1.0                 7.0
# 4               100.0               17.0                98.0
#
#             aniongap        bicarbonate                bun  \
# 0                100                100                100
# 1              17.31              28.58              29.63
# 2  4.877685740370957  4.346553261208844  28.62493615184093
# 3                9.0               17.0                8.0
# 4               40.0               46.0              205.0
#
#               calcium           chloride          creatinine  \
# 0                  99                100                 100
# 1   9.033333333333333             107.09  1.6050000000000006
# 2  0.6969320524371697  5.884571506760864  1.9878608877612411
# 3                 7.8               92.0                 0.3
# 4                12.1              136.0                15.2
#
#               glucose             sodium           potassium  \
# 0                 100                100                 100
# 1              202.79             141.59   4.664000000000001
# 2  133.43937412044681  5.444105328544153  0.7135796799208618
# 3                88.0              130.0                 3.5
# 4               942.0              168.0                 7.4
#
#                   inr                  pt                ptt  \
# 0                  97                  97                 96
# 1  1.7391752577319581  18.823711340206195  50.60520833333334
# 2  1.2033422813348285  12.426607652498767  35.88793484340609
# 3                 0.9                10.0               20.1
# 4                 9.6                94.3              150.0
#
#           hematocrit          hemoglobin                 mch  \
# 0                100                 100                 100
# 1  36.85900000000001  12.152000000000003  30.682999999999993
# 2  4.727121297108394  1.7362725662298604  2.7497678506236176
# 3               26.0                 7.7                21.1
# 4               50.3                16.9                37.9
#
#                  mchc                mcv           platelet  \
# 0                 100                100                100
# 1   33.94500000000002              92.99             303.31
# 2  1.7079360217951531  7.395733140593211  144.0438832544801
# 3                27.8               76.0               63.0
# 4                37.6              124.0              886.0
#
#                   rbc                 rdw                wbc  \
# 0                 100                 100                100
# 1              4.0609  14.894999999999998              14.49
# 2  0.5850167829760412  2.3226758775867187  8.628745709849868
# 3                2.69                12.0                2.4
# 4                5.86                29.3               62.4
#
#               scr_min                  ckd             mdrd_est  \
# 0                 100                  100                  100
# 1  0.9280000000000005                 0.17   0.9653000000000003
# 2   0.877102668396973  0.37752516806863695  0.12674204296343597
# 3                 0.1                  0.0                 0.77
# 4                 6.0                  1.0                 1.22
#
#          scr_baseline                alt                 alp  \
# 0                 100                 68                  67
# 1  0.9094000000000004             233.25  121.23880597014926
# 2  0.8670614718459101  991.1271041431388   76.99804986752052
# 3                 0.1                7.0                32.0
# 4                 6.0             8010.0               414.0
#
#                   ast     bilirubin_total gender     db_wbc_imputed  \
# 0                  69                  68    100                100
# 1  428.07246376811594  2.0500000000000007   None              14.49
# 2  1737.8582095316315   5.262554285890104   None  8.628745709849868
# 3                 5.0                 0.2      F                2.4
# 4             13060.0                35.9      M               62.4
#
#   basophils_abs_imputed eosinophils_abs_imputed lymphocytes_abs_imputed  \
# 0                   100                     100                     100
# 1                 0.053      0.2059000000000001      2.6220999999999974
# 2   0.05030211755287276     0.25499889086706706       5.648449916087196
# 3                   0.0                     0.0                    0.25
# 4                  0.26                     1.9                   57.41
#
#   monocytes_abs_imputed neutrophils_abs_imputed   basophils_imputed  \
# 0                   100                     100                 100
# 1    0.8860999999999991      12.283100000000005  0.4040000000000001
# 2    0.4903634912341593       6.260836697400367  0.4664328418535684
# 3                  0.26                    2.73                 0.0
# 4                  3.84                    40.8                 4.0
#
#   eosinophils_imputed lymphocytes_imputed  monocytes_imputed  \
# 0                 100                 100                100
# 1  1.6249999999999998  17.330000000000013  6.344000000000005
# 2  2.2373493967711706  13.629220688126544  2.617706606705167
# 3                 0.0                 2.0                1.0
# 4                18.0               100.0               17.0
#
#   neutrophils_imputed   aniongap_imputed bicarbonate_imputed  \
# 0                 100                100                 100
# 1   79.85400000000001              17.31               28.58
# 2  11.071634700869378  4.877685740370957   4.346553261208844
# 3                 7.0                9.0                17.0
# 4                98.0               40.0                46.0
#
#          bun_imputed     calcium_imputed   chloride_imputed  \
# 0                100                 100                100
# 1              29.63               9.033             107.09
# 2  28.62493615184093  0.6934112718431914  5.884571506760864
# 3                8.0                 7.8               92.0
# 4              205.0                12.1              136.0
#
#    creatinine_imputed     glucose_imputed     sodium_imputed  \
# 0                 100                 100                100
# 1  1.6050000000000006              202.79             141.59
# 2  1.9878608877612411  133.43937412044681  5.444105328544153
# 3                 0.3                88.0              130.0
# 4                15.2               942.0              168.0
#
#     potassium_imputed         inr_imputed          pt_imputed  \
# 0                 100                 100                 100
# 1   4.664000000000001  1.7289999999999994  18.724000000000007
# 2  0.7135796799208618   1.186395525714061  12.250138073845653
# 3                 3.5                 0.9                10.0
# 4                 7.4                 9.6                94.3
#
#           ptt_imputed hematocrit_imputed  hemoglobin_imputed  \
# 0                 100                100                 100
# 1              49.925  36.85900000000001  12.152000000000003
# 2  35.314618757389944  4.727121297108394  1.7362725662298604
# 3                20.1               26.0                 7.7
# 4               150.0               50.3                16.9
#
#           mch_imputed        mchc_imputed        mcv_imputed  \
# 0                 100                 100                100
# 1  30.682999999999993   33.94500000000002              92.99
# 2  2.7497678506236176  1.7079360217951531  7.395733140593211
# 3                21.1                27.8               76.0
# 4                37.9                37.6              124.0
#
#     platelet_imputed         rbc_imputed         rdw_imputed  \
# 0                100                 100                 100
# 1             303.31              4.0609  14.894999999999998
# 2  144.0438832544801  0.5850167829760412  2.3226758775867187
# 3               63.0                2.69                12.0
# 4              886.0                5.86                29.3
#
#          wbc_imputed     scr_min_imputed          ckd_imputed  \
# 0                100                 100                  100
# 1              14.49  0.9280000000000005                 0.17
# 2  8.628745709849868   0.877102668396973  0.37752516806863695
# 3                2.4                 0.1                  0.0
# 4               62.4                 6.0                  1.0
#
#       mdrd_est_imputed scr_baseline_imputed        alt_imputed  \
# 0                  100                  100                100
# 1   0.9653000000000003   0.9094000000000004             170.77
# 2  0.12674204296343597   0.8670614718459101  820.4818349696424
# 3                 0.77                  0.1                7.0
# 4                 1.22                  6.0             8010.0
#
#          alp_imputed         ast_imputed bilirubin_total_imputed
# 0                100                 100                     100
# 1             113.57              308.39      1.5859999999999994
# 2  63.82065385583149  1451.4308502406523       4.382334141214305
# 3               32.0                 5.0                     0.2
# 4              414.0             13060.0                    35.9

# %%
cluster_data.groupby("gender").count().toPandas()
# Out:
#   gender  count
# 0      F     43
# 1      M     57

# %%
# replace gender M, F to 1, 2, anyother values to 0
cluster_data = cluster_data.withColumn("gender_imputed", F.when(F.col("gender") == 'M', 1) \
                           .when(F.col("gender") == 'F', 2) \
                           .otherwise(0))
cluster_data.groupby("gender_imputed").count().toPandas()
# Out:
#    gender_imputed  count
# 0               1     57
# 1               2     43

# %%
# get all the columns to be used for clustering
cluster_cols = [c for c in cluster_data.columns if "_imputed" in c]
cluster_cols.extend(["age"])
cluster_cols
# Out:
# ['db_wbc_imputed',
#  'basophils_abs_imputed',
#  'eosinophils_abs_imputed',
#  'lymphocytes_abs_imputed',
#  'monocytes_abs_imputed',
#  'neutrophils_abs_imputed',
#  'basophils_imputed',
#  'eosinophils_imputed',
#  'lymphocytes_imputed',
#  'monocytes_imputed',
#  'neutrophils_imputed',
#  'aniongap_imputed',
#  'bicarbonate_imputed',
#  'bun_imputed',
#  'calcium_imputed',
#  'chloride_imputed',
#  'creatinine_imputed',
#  'glucose_imputed',
#  'sodium_imputed',
#  'potassium_imputed',
#  'inr_imputed',
#  'pt_imputed',
#  'ptt_imputed',
#  'hematocrit_imputed',
#  'hemoglobin_imputed',
#  'mch_imputed',
#  'mchc_imputed',
#  'mcv_imputed',
#  'platelet_imputed',
#  'rbc_imputed',
#  'rdw_imputed',
#  'wbc_imputed',
#  'scr_min_imputed',
#  'ckd_imputed',
#  'mdrd_est_imputed',
#  'scr_baseline_imputed',
#  'alt_imputed',
#  'alp_imputed',
#  'ast_imputed',
#  'bilirubin_total_imputed',
#  'gender_imputed',
#  'age']

# %%
from pyspark.ml.feature import VectorAssembler
assemble = VectorAssembler(inputCols=cluster_cols, outputCol='features')
assembled_data = assemble.setHandleInvalid("skip").transform(cluster_data)
assembled_data.toPandas()
# Out:
#       age  db_wbc  basophils_abs  eosinophils_abs  lymphocytes_abs  \
# 0   52.35     4.2            NaN              NaN              NaN
# 1   55.88    19.0           0.13             0.29             5.17
# 2   46.28    20.1           0.22             0.42             5.73
# 3   80.53     6.0           0.17             1.90             6.01
# 4   81.39    36.8           0.00             0.22             1.79
# ..    ...     ...            ...              ...              ...
# 95  45.39    11.5           0.03             0.26             1.56
# 96  46.83     7.0           0.21             0.39             6.32
# 97  57.99    15.3            NaN              NaN              NaN
# 98  67.68     8.5           0.02             0.16             1.33
# 99  64.21     8.9           0.01             0.11             1.08
#
#     monocytes_abs  neutrophils_abs  basophils  eosinophils  lymphocytes  \
# 0             NaN              NaN        NaN          NaN          NaN
# 1            1.18            12.24        0.7          1.5         27.2
# 2            0.94            18.99        1.1          2.1         28.5
# 3            1.17            28.49        0.5          5.7         18.0
# 4            2.21            33.49        0.0          2.0         16.0
# ..            ...              ...        ...          ...          ...
# 95           1.17             7.60        0.3          3.0         17.4
# 96           1.64            14.35        1.0          3.0         49.0
# 97            NaN              NaN        NaN          NaN          NaN
# 98           0.50             2.75        0.4          3.4         27.9
# 99           0.92             9.08        0.1          1.0          9.5
#
#     monocytes  neutrophils  aniongap  bicarbonate   bun  calcium  chloride  \
# 0         NaN          NaN       9.0         28.0  25.0      7.8     105.0
# 1         6.2         64.4      16.0         30.0  11.0      8.9     108.0
# 2         4.7         94.5      16.0         32.0  18.0      9.1     106.0
# 3         3.5         85.3      11.0         28.0  12.0      9.3     101.0
# 4         6.0         81.0      23.0         22.0  45.0      8.7     103.0
# ..        ...          ...       ...          ...   ...      ...       ...
# 95       12.8         75.0      20.0         33.0  24.0      9.3     105.0
# 96        9.2         78.0      18.0         25.0  15.0      9.0     111.0
# 97        NaN          NaN      14.0         27.0   8.0      8.2     106.0
# 98       10.5         57.6      17.0         24.0  14.0      9.1     111.0
# 99        8.1         80.1      21.0         29.0  36.0      9.3      98.0
#
#     creatinine  glucose  sodium  potassium  inr    pt    ptt  hematocrit  \
# 0          0.3     99.0   137.0        4.5  1.5  16.6   32.3        37.6
# 1          0.7    113.0   142.0        4.2  1.2  12.6   36.6        38.1
# 2          0.9    152.0   141.0        4.0  1.0  11.3   31.8        39.1
# 3          0.8    100.0   136.0        4.4  1.5  16.0   48.4        34.1
# 4          1.6    370.0   137.0        4.8  1.7  18.9   62.5        43.0
# ..         ...      ...     ...        ...  ...   ...    ...         ...
# 95         0.9    140.0   140.0        6.2  1.7  18.9   31.8        33.6
# 96         0.9     88.0   144.0        4.7  5.7  64.4  150.0        33.3
# 97         0.7    176.0   139.0        4.1  1.7  18.7   78.3        34.4
# 98         0.9    137.0   148.0        3.5  1.1  11.7   29.2        34.2
# 99         1.5    344.0   138.0        3.8  2.8  29.6   44.6        35.0
#
#     hemoglobin   mch  mchc    mcv  platelet   rbc   rdw   wbc  scr_min  ckd  \
# 0         12.7  33.4  33.8   99.0      71.0  3.80  15.3   4.2      0.3  0.0
# 1         12.9  28.3  34.4   86.0     474.0  4.71  14.1  19.0      0.4  0.0
# 2         13.9  33.0  35.6   94.0     330.0  4.33  12.0  20.1      0.8  0.0
# 3         11.8  32.7  34.7   94.0     308.0  3.62  13.3   6.0      0.8  0.0
# 4         14.3  31.8  34.5   97.0     216.0  4.58  13.2  36.8      1.1  0.0
# ..         ...   ...   ...    ...       ...   ...   ...   ...      ...  ...
# 95        10.1  25.3  31.9   84.0     348.0  4.24  15.4  11.5      0.6  0.0
# 96        10.4  37.9  32.3  124.0     345.0  2.74  17.6   7.0      0.8  0.0
# 97        12.3  32.0  36.4   89.0     184.0  3.95  14.3  15.3      0.4  0.0
# 98        10.9  29.6  31.9   93.0     157.0  3.68  14.4   8.5      0.9  0.0
# 99        11.4  32.0  33.5  104.0     202.0  3.67  14.3   8.9      1.5  1.0
#
#     mdrd_est  scr_baseline     alt    alp     ast  bilirubin_total gender  \
# 0       0.85           0.3    88.0  103.0    98.0              1.3      F
# 1       0.84           0.4    12.0   56.0    17.0              0.4      F
# 2       0.86           0.8     NaN    NaN     NaN              NaN      F
# 3       0.78           0.8    66.0  163.0   102.0              0.2      F
# 4       1.01           1.1    44.0   99.0   210.0              0.6      M
# ..       ...           ...     ...    ...     ...              ...    ...
# 95      1.12           0.6    54.0  127.0    36.0              1.5      M
# 96      0.86           0.8    70.0  325.0   139.0              4.6      F
# 97      0.83           0.4  1343.0  125.0  1015.0              2.0      F
# 98      0.81           0.9    16.0   73.0    15.0              0.2      F
# 99      0.82           1.5     7.0  199.0    16.0              0.7      F
#
#     db_wbc_imputed  basophils_abs_imputed  eosinophils_abs_imputed  \
# 0              4.2                   0.04                     0.15
# 1             19.0                   0.13                     0.29
# 2             20.1                   0.22                     0.42
# 3              6.0                   0.17                     1.90
# 4             36.8                   0.00                     0.22
# ..             ...                    ...                      ...
# 95            11.5                   0.03                     0.26
# 96             7.0                   0.21                     0.39
# 97            15.3                   0.04                     0.15
# 98             8.5                   0.02                     0.16
# 99             8.9                   0.01                     0.11
#
#     lymphocytes_abs_imputed  monocytes_abs_imputed  neutrophils_abs_imputed  \
# 0                      1.92                   0.82                    11.70
# 1                      5.17                   1.18                    12.24
# 2                      5.73                   0.94                    18.99
# 3                      6.01                   1.17                    28.49
# 4                      1.79                   2.21                    33.49
# ..                      ...                    ...                      ...
# 95                     1.56                   1.17                     7.60
# 96                     6.32                   1.64                    14.35
# 97                     1.92                   0.82                    11.70
# 98                     1.33                   0.50                     2.75
# 99                     1.08                   0.92                     9.08
#
#     basophils_imputed  eosinophils_imputed  lymphocytes_imputed  \
# 0                 0.3                  1.0                 15.4
# 1                 0.7                  1.5                 27.2
# 2                 1.1                  2.1                 28.5
# 3                 0.5                  5.7                 18.0
# 4                 0.0                  2.0                 16.0
# ..                ...                  ...                  ...
# 95                0.3                  3.0                 17.4
# 96                1.0                  3.0                 49.0
# 97                0.3                  1.0                 15.4
# 98                0.4                  3.4                 27.9
# 99                0.1                  1.0                  9.5
#
#     monocytes_imputed  neutrophils_imputed  aniongap_imputed  \
# 0                 6.1                 81.5               9.0
# 1                 6.2                 64.4              16.0
# 2                 4.7                 94.5              16.0
# 3                 3.5                 85.3              11.0
# 4                 6.0                 81.0              23.0
# ..                ...                  ...               ...
# 95               12.8                 75.0              20.0
# 96                9.2                 78.0              18.0
# 97                6.1                 81.5              14.0
# 98               10.5                 57.6              17.0
# 99                8.1                 80.1              21.0
#
#     bicarbonate_imputed  bun_imputed  calcium_imputed  chloride_imputed  \
# 0                  28.0         25.0              7.8             105.0
# 1                  30.0         11.0              8.9             108.0
# 2                  32.0         18.0              9.1             106.0
# 3                  28.0         12.0              9.3             101.0
# 4                  22.0         45.0              8.7             103.0
# ..                  ...          ...              ...               ...
# 95                 33.0         24.0              9.3             105.0
# 96                 25.0         15.0              9.0             111.0
# 97                 27.0          8.0              8.2             106.0
# 98                 24.0         14.0              9.1             111.0
# 99                 29.0         36.0              9.3              98.0
#
#     creatinine_imputed  glucose_imputed  sodium_imputed  potassium_imputed  \
# 0                  0.3             99.0           137.0                4.5
# 1                  0.7            113.0           142.0                4.2
# 2                  0.9            152.0           141.0                4.0
# 3                  0.8            100.0           136.0                4.4
# 4                  1.6            370.0           137.0                4.8
# ..                 ...              ...             ...                ...
# 95                 0.9            140.0           140.0                6.2
# 96                 0.9             88.0           144.0                4.7
# 97                 0.7            176.0           139.0                4.1
# 98                 0.9            137.0           148.0                3.5
# 99                 1.5            344.0           138.0                3.8
#
#     inr_imputed  pt_imputed  ptt_imputed  hematocrit_imputed  \
# 0           1.5        16.6         32.3                37.6
# 1           1.2        12.6         36.6                38.1
# 2           1.0        11.3         31.8                39.1
# 3           1.5        16.0         48.4                34.1
# 4           1.7        18.9         62.5                43.0
# ..          ...         ...          ...                 ...
# 95          1.7        18.9         31.8                33.6
# 96          5.7        64.4        150.0                33.3
# 97          1.7        18.7         78.3                34.4
# 98          1.1        11.7         29.2                34.2
# 99          2.8        29.6         44.6                35.0
#
#     hemoglobin_imputed  mch_imputed  mchc_imputed  mcv_imputed  \
# 0                 12.7         33.4          33.8         99.0
# 1                 12.9         28.3          34.4         86.0
# 2                 13.9         33.0          35.6         94.0
# 3                 11.8         32.7          34.7         94.0
# 4                 14.3         31.8          34.5         97.0
# ..                 ...          ...           ...          ...
# 95                10.1         25.3          31.9         84.0
# 96                10.4         37.9          32.3        124.0
# 97                12.3         32.0          36.4         89.0
# 98                10.9         29.6          31.9         93.0
# 99                11.4         32.0          33.5        104.0
#
#     platelet_imputed  rbc_imputed  rdw_imputed  wbc_imputed  scr_min_imputed  \
# 0               71.0         3.80         15.3          4.2              0.3
# 1              474.0         4.71         14.1         19.0              0.4
# 2              330.0         4.33         12.0         20.1              0.8
# 3              308.0         3.62         13.3          6.0              0.8
# 4              216.0         4.58         13.2         36.8              1.1
# ..               ...          ...          ...          ...              ...
# 95             348.0         4.24         15.4         11.5              0.6
# 96             345.0         2.74         17.6          7.0              0.8
# 97             184.0         3.95         14.3         15.3              0.4
# 98             157.0         3.68         14.4          8.5              0.9
# 99             202.0         3.67         14.3          8.9              1.5
#
#     ckd_imputed  mdrd_est_imputed  scr_baseline_imputed  alt_imputed  \
# 0           0.0              0.85                   0.3         88.0
# 1           0.0              0.84                   0.4         12.0
# 2           0.0              0.86                   0.8         38.0
# 3           0.0              0.78                   0.8         66.0
# 4           0.0              1.01                   1.1         44.0
# ..          ...               ...                   ...          ...
# 95          0.0              1.12                   0.6         54.0
# 96          0.0              0.86                   0.8         70.0
# 97          0.0              0.83                   0.4       1343.0
# 98          0.0              0.81                   0.9         16.0
# 99          1.0              0.82                   1.5          7.0
#
#     alp_imputed  ast_imputed  bilirubin_total_imputed  gender_imputed  \
# 0         103.0         98.0                      1.3               2
# 1          56.0         17.0                      0.4               2
# 2          98.0         42.0                      0.6               2
# 3         163.0        102.0                      0.2               2
# 4          99.0        210.0                      0.6               1
# ..          ...          ...                      ...             ...
# 95        127.0         36.0                      1.5               1
# 96        325.0        139.0                      4.6               2
# 97        125.0       1015.0                      2.0               2
# 98         73.0         15.0                      0.2               2
# 99        199.0         16.0                      0.7               2
#
#                                              features
# 0   [4.2, 0.04, 0.15, 1.92, 0.82, 11.7, 0.3, 1.0, ...
# 1   [19.0, 0.13, 0.29, 5.17, 1.18, 12.24, 0.7, 1.5...
# 2   [20.1, 0.22, 0.42, 5.73, 0.94, 18.99, 1.1, 2.1...
# 3   [6.0, 0.17, 1.9, 6.01, 1.17, 28.49, 0.5, 5.7, ...
# 4   [36.8, 0.0, 0.22, 1.79, 2.21, 33.49, 0.0, 2.0,...
# ..                                                ...
# 95  [11.5, 0.03, 0.26, 1.56, 1.17, 7.6, 0.3, 3.0, ...
# 96  [7.0, 0.21, 0.39, 6.32, 1.64, 14.35, 1.0, 3.0,...
# 97  [15.3, 0.04, 0.15, 1.92, 0.82, 11.7, 0.3, 1.0,...
# 98  [8.5, 0.02, 0.16, 1.33, 0.5, 2.75, 0.4, 3.4, 2...
# 99  [8.9, 0.01, 0.11, 1.08, 0.92, 9.08, 0.1, 1.0, ...
#
# [100 rows x 84 columns]

# %%
print(cluster_data.count())
print(assembled_data.count())
# Out:
# 100
# 100

# %%
from pyspark.ml.feature import StandardScaler
scale=StandardScaler(inputCol='features',outputCol='standardized')
data_scale=scale.fit(assembled_data)
data_scale_output=data_scale.transform(assembled_data)
print(data_scale_output.count())
data_scale_output.toPandas()
# Out:
# 100
#       age  db_wbc  basophils_abs  eosinophils_abs  lymphocytes_abs  \
# 0   52.35     4.2            NaN              NaN              NaN
# 1   55.88    19.0           0.13             0.29             5.17
# 2   46.28    20.1           0.22             0.42             5.73
# 3   80.53     6.0           0.17             1.90             6.01
# 4   81.39    36.8           0.00             0.22             1.79
# ..    ...     ...            ...              ...              ...
# 95  45.39    11.5           0.03             0.26             1.56
# 96  46.83     7.0           0.21             0.39             6.32
# 97  57.99    15.3            NaN              NaN              NaN
# 98  67.68     8.5           0.02             0.16             1.33
# 99  64.21     8.9           0.01             0.11             1.08
#
#     monocytes_abs  neutrophils_abs  basophils  eosinophils  lymphocytes  \
# 0             NaN              NaN        NaN          NaN          NaN
# 1            1.18            12.24        0.7          1.5         27.2
# 2            0.94            18.99        1.1          2.1         28.5
# 3            1.17            28.49        0.5          5.7         18.0
# 4            2.21            33.49        0.0          2.0         16.0
# ..            ...              ...        ...          ...          ...
# 95           1.17             7.60        0.3          3.0         17.4
# 96           1.64            14.35        1.0          3.0         49.0
# 97            NaN              NaN        NaN          NaN          NaN
# 98           0.50             2.75        0.4          3.4         27.9
# 99           0.92             9.08        0.1          1.0          9.5
#
#     monocytes  neutrophils  aniongap  bicarbonate   bun  calcium  chloride  \
# 0         NaN          NaN       9.0         28.0  25.0      7.8     105.0
# 1         6.2         64.4      16.0         30.0  11.0      8.9     108.0
# 2         4.7         94.5      16.0         32.0  18.0      9.1     106.0
# 3         3.5         85.3      11.0         28.0  12.0      9.3     101.0
# 4         6.0         81.0      23.0         22.0  45.0      8.7     103.0
# ..        ...          ...       ...          ...   ...      ...       ...
# 95       12.8         75.0      20.0         33.0  24.0      9.3     105.0
# 96        9.2         78.0      18.0         25.0  15.0      9.0     111.0
# 97        NaN          NaN      14.0         27.0   8.0      8.2     106.0
# 98       10.5         57.6      17.0         24.0  14.0      9.1     111.0
# 99        8.1         80.1      21.0         29.0  36.0      9.3      98.0
#
#     creatinine  glucose  sodium  potassium  inr    pt    ptt  hematocrit  \
# 0          0.3     99.0   137.0        4.5  1.5  16.6   32.3        37.6
# 1          0.7    113.0   142.0        4.2  1.2  12.6   36.6        38.1
# 2          0.9    152.0   141.0        4.0  1.0  11.3   31.8        39.1
# 3          0.8    100.0   136.0        4.4  1.5  16.0   48.4        34.1
# 4          1.6    370.0   137.0        4.8  1.7  18.9   62.5        43.0
# ..         ...      ...     ...        ...  ...   ...    ...         ...
# 95         0.9    140.0   140.0        6.2  1.7  18.9   31.8        33.6
# 96         0.9     88.0   144.0        4.7  5.7  64.4  150.0        33.3
# 97         0.7    176.0   139.0        4.1  1.7  18.7   78.3        34.4
# 98         0.9    137.0   148.0        3.5  1.1  11.7   29.2        34.2
# 99         1.5    344.0   138.0        3.8  2.8  29.6   44.6        35.0
#
#     hemoglobin   mch  mchc    mcv  platelet   rbc   rdw   wbc  scr_min  ckd  \
# 0         12.7  33.4  33.8   99.0      71.0  3.80  15.3   4.2      0.3  0.0
# 1         12.9  28.3  34.4   86.0     474.0  4.71  14.1  19.0      0.4  0.0
# 2         13.9  33.0  35.6   94.0     330.0  4.33  12.0  20.1      0.8  0.0
# 3         11.8  32.7  34.7   94.0     308.0  3.62  13.3   6.0      0.8  0.0
# 4         14.3  31.8  34.5   97.0     216.0  4.58  13.2  36.8      1.1  0.0
# ..         ...   ...   ...    ...       ...   ...   ...   ...      ...  ...
# 95        10.1  25.3  31.9   84.0     348.0  4.24  15.4  11.5      0.6  0.0
# 96        10.4  37.9  32.3  124.0     345.0  2.74  17.6   7.0      0.8  0.0
# 97        12.3  32.0  36.4   89.0     184.0  3.95  14.3  15.3      0.4  0.0
# 98        10.9  29.6  31.9   93.0     157.0  3.68  14.4   8.5      0.9  0.0
# 99        11.4  32.0  33.5  104.0     202.0  3.67  14.3   8.9      1.5  1.0
#
#     mdrd_est  scr_baseline     alt    alp     ast  bilirubin_total gender  \
# 0       0.85           0.3    88.0  103.0    98.0              1.3      F
# 1       0.84           0.4    12.0   56.0    17.0              0.4      F
# 2       0.86           0.8     NaN    NaN     NaN              NaN      F
# 3       0.78           0.8    66.0  163.0   102.0              0.2      F
# 4       1.01           1.1    44.0   99.0   210.0              0.6      M
# ..       ...           ...     ...    ...     ...              ...    ...
# 95      1.12           0.6    54.0  127.0    36.0              1.5      M
# 96      0.86           0.8    70.0  325.0   139.0              4.6      F
# 97      0.83           0.4  1343.0  125.0  1015.0              2.0      F
# 98      0.81           0.9    16.0   73.0    15.0              0.2      F
# 99      0.82           1.5     7.0  199.0    16.0              0.7      F
#
#     db_wbc_imputed  basophils_abs_imputed  eosinophils_abs_imputed  \
# 0              4.2                   0.04                     0.15
# 1             19.0                   0.13                     0.29
# 2             20.1                   0.22                     0.42
# 3              6.0                   0.17                     1.90
# 4             36.8                   0.00                     0.22
# ..             ...                    ...                      ...
# 95            11.5                   0.03                     0.26
# 96             7.0                   0.21                     0.39
# 97            15.3                   0.04                     0.15
# 98             8.5                   0.02                     0.16
# 99             8.9                   0.01                     0.11
#
#     lymphocytes_abs_imputed  monocytes_abs_imputed  neutrophils_abs_imputed  \
# 0                      1.92                   0.82                    11.70
# 1                      5.17                   1.18                    12.24
# 2                      5.73                   0.94                    18.99
# 3                      6.01                   1.17                    28.49
# 4                      1.79                   2.21                    33.49
# ..                      ...                    ...                      ...
# 95                     1.56                   1.17                     7.60
# 96                     6.32                   1.64                    14.35
# 97                     1.92                   0.82                    11.70
# 98                     1.33                   0.50                     2.75
# 99                     1.08                   0.92                     9.08
#
#     basophils_imputed  eosinophils_imputed  lymphocytes_imputed  \
# 0                 0.3                  1.0                 15.4
# 1                 0.7                  1.5                 27.2
# 2                 1.1                  2.1                 28.5
# 3                 0.5                  5.7                 18.0
# 4                 0.0                  2.0                 16.0
# ..                ...                  ...                  ...
# 95                0.3                  3.0                 17.4
# 96                1.0                  3.0                 49.0
# 97                0.3                  1.0                 15.4
# 98                0.4                  3.4                 27.9
# 99                0.1                  1.0                  9.5
#
#     monocytes_imputed  neutrophils_imputed  aniongap_imputed  \
# 0                 6.1                 81.5               9.0
# 1                 6.2                 64.4              16.0
# 2                 4.7                 94.5              16.0
# 3                 3.5                 85.3              11.0
# 4                 6.0                 81.0              23.0
# ..                ...                  ...               ...
# 95               12.8                 75.0              20.0
# 96                9.2                 78.0              18.0
# 97                6.1                 81.5              14.0
# 98               10.5                 57.6              17.0
# 99                8.1                 80.1              21.0
#
#     bicarbonate_imputed  bun_imputed  calcium_imputed  chloride_imputed  \
# 0                  28.0         25.0              7.8             105.0
# 1                  30.0         11.0              8.9             108.0
# 2                  32.0         18.0              9.1             106.0
# 3                  28.0         12.0              9.3             101.0
# 4                  22.0         45.0              8.7             103.0
# ..                  ...          ...              ...               ...
# 95                 33.0         24.0              9.3             105.0
# 96                 25.0         15.0              9.0             111.0
# 97                 27.0          8.0              8.2             106.0
# 98                 24.0         14.0              9.1             111.0
# 99                 29.0         36.0              9.3              98.0
#
#     creatinine_imputed  glucose_imputed  sodium_imputed  potassium_imputed  \
# 0                  0.3             99.0           137.0                4.5
# 1                  0.7            113.0           142.0                4.2
# 2                  0.9            152.0           141.0                4.0
# 3                  0.8            100.0           136.0                4.4
# 4                  1.6            370.0           137.0                4.8
# ..                 ...              ...             ...                ...
# 95                 0.9            140.0           140.0                6.2
# 96                 0.9             88.0           144.0                4.7
# 97                 0.7            176.0           139.0                4.1
# 98                 0.9            137.0           148.0                3.5
# 99                 1.5            344.0           138.0                3.8
#
#     inr_imputed  pt_imputed  ptt_imputed  hematocrit_imputed  \
# 0           1.5        16.6         32.3                37.6
# 1           1.2        12.6         36.6                38.1
# 2           1.0        11.3         31.8                39.1
# 3           1.5        16.0         48.4                34.1
# 4           1.7        18.9         62.5                43.0
# ..          ...         ...          ...                 ...
# 95          1.7        18.9         31.8                33.6
# 96          5.7        64.4        150.0                33.3
# 97          1.7        18.7         78.3                34.4
# 98          1.1        11.7         29.2                34.2
# 99          2.8        29.6         44.6                35.0
#
#     hemoglobin_imputed  mch_imputed  mchc_imputed  mcv_imputed  \
# 0                 12.7         33.4          33.8         99.0
# 1                 12.9         28.3          34.4         86.0
# 2                 13.9         33.0          35.6         94.0
# 3                 11.8         32.7          34.7         94.0
# 4                 14.3         31.8          34.5         97.0
# ..                 ...          ...           ...          ...
# 95                10.1         25.3          31.9         84.0
# 96                10.4         37.9          32.3        124.0
# 97                12.3         32.0          36.4         89.0
# 98                10.9         29.6          31.9         93.0
# 99                11.4         32.0          33.5        104.0
#
#     platelet_imputed  rbc_imputed  rdw_imputed  wbc_imputed  scr_min_imputed  \
# 0               71.0         3.80         15.3          4.2              0.3
# 1              474.0         4.71         14.1         19.0              0.4
# 2              330.0         4.33         12.0         20.1              0.8
# 3              308.0         3.62         13.3          6.0              0.8
# 4              216.0         4.58         13.2         36.8              1.1
# ..               ...          ...          ...          ...              ...
# 95             348.0         4.24         15.4         11.5              0.6
# 96             345.0         2.74         17.6          7.0              0.8
# 97             184.0         3.95         14.3         15.3              0.4
# 98             157.0         3.68         14.4          8.5              0.9
# 99             202.0         3.67         14.3          8.9              1.5
#
#     ckd_imputed  mdrd_est_imputed  scr_baseline_imputed  alt_imputed  \
# 0           0.0              0.85                   0.3         88.0
# 1           0.0              0.84                   0.4         12.0
# 2           0.0              0.86                   0.8         38.0
# 3           0.0              0.78                   0.8         66.0
# 4           0.0              1.01                   1.1         44.0
# ..          ...               ...                   ...          ...
# 95          0.0              1.12                   0.6         54.0
# 96          0.0              0.86                   0.8         70.0
# 97          0.0              0.83                   0.4       1343.0
# 98          0.0              0.81                   0.9         16.0
# 99          1.0              0.82                   1.5          7.0
#
#     alp_imputed  ast_imputed  bilirubin_total_imputed  gender_imputed  \
# 0         103.0         98.0                      1.3               2
# 1          56.0         17.0                      0.4               2
# 2          98.0         42.0                      0.6               2
# 3         163.0        102.0                      0.2               2
# 4          99.0        210.0                      0.6               1
# ..          ...          ...                      ...             ...
# 95        127.0         36.0                      1.5               1
# 96        325.0        139.0                      4.6               2
# 97        125.0       1015.0                      2.0               2
# 98         73.0         15.0                      0.2               2
# 99        199.0         16.0                      0.7               2
#
#                                              features  \
# 0   [4.2, 0.04, 0.15, 1.92, 0.82, 11.7, 0.3, 1.0, ...
# 1   [19.0, 0.13, 0.29, 5.17, 1.18, 12.24, 0.7, 1.5...
# 2   [20.1, 0.22, 0.42, 5.73, 0.94, 18.99, 1.1, 2.1...
# 3   [6.0, 0.17, 1.9, 6.01, 1.17, 28.49, 0.5, 5.7, ...
# 4   [36.8, 0.0, 0.22, 1.79, 2.21, 33.49, 0.0, 2.0,...
# ..                                                ...
# 95  [11.5, 0.03, 0.26, 1.56, 1.17, 7.6, 0.3, 3.0, ...
# 96  [7.0, 0.21, 0.39, 6.32, 1.64, 14.35, 1.0, 3.0,...
# 97  [15.3, 0.04, 0.15, 1.92, 0.82, 11.7, 0.3, 1.0,...
# 98  [8.5, 0.02, 0.16, 1.33, 0.5, 2.75, 0.4, 3.4, 2...
# 99  [8.9, 0.01, 0.11, 1.08, 0.92, 9.08, 0.1, 1.0, ...
#
#                                          standardized
# 0   [0.486745135530605, 0.7951951517340367, 0.5882...
# 1   [2.201942279781308, 2.584384243135619, 1.13725...
# 2   [2.3294231486107524, 4.373573334537201, 1.6470...
# 3   [0.6953501936151499, 3.3795793948696558, 7.451...
# 4   [4.264814520839586, 0.0, 0.8627488506006397, 0...
# ..                                                ...
# 95  [1.3327545377623706, 0.5963963638005274, 1.019...
# 96  [0.8112418925510083, 4.174774546603692, 1.5294...
# 97  [1.7731429937186325, 0.7951951517340367, 0.588...
# 98  [0.9850794409547957, 0.3975975758670183, 0.627...
# 99  [1.0314361205291391, 0.19879878793350916, 0.43...
#
# [100 rows x 85 columns]

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
silhouette_score=[]

evaluator = ClusteringEvaluator(predictionCol='prediction', featuresCol='standardized', \
                                metricName='silhouette', distanceMeasure='squaredEuclidean')
for i in range(2,10):
    
    KMeans_algo=KMeans(featuresCol='standardized', k=i)
    
    KMeans_fit=KMeans_algo.fit(data_scale_output)
    
    output=KMeans_fit.transform(data_scale_output)
    
    
    
    score=evaluator.evaluate(output)
    
    silhouette_score.append(score)
    
    print("Silhouette Score {}:".format(i),score)
# Out:
# Silhouette Score 2: 0.44919495330174386
# Silhouette Score 3: 0.48747916235599426
# Silhouette Score 4: 0.3948508207230857
# Silhouette Score 5: 0.343654627323389
# Silhouette Score 6: 0.1001955190306208
# Silhouette Score 7: 0.07049995920096758
# Silhouette Score 8: 0.07917236143718873
# Silhouette Score 9: 0.0884453790394462

# %%
#Visualizing the silhouette scores in a plot
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize =(8,6))
ax.plot(range(2,10), silhouette_score)
ax.set_xlabel('k')
ax.set_ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
silhouette_score=[]

evaluator = ClusteringEvaluator(predictionCol='prediction', featuresCol='standardized', \
                                metricName='silhouette', distanceMeasure='cosine')
for i in range(2,10):
    
    KMeans_algo=KMeans(featuresCol='standardized', k=i)
    
    KMeans_fit=KMeans_algo.fit(data_scale_output)
    
    output=KMeans_fit.transform(data_scale_output)
    
    
    
    score=evaluator.evaluate(output)
    
    silhouette_score.append(score)
    
    print("Silhouette Score {}:".format(i),score)
# Out:
# Silhouette Score 2: 0.43111754144135184
# Silhouette Score 3: 0.47238578787351637
# Silhouette Score 4: 0.38913746327764154
# Silhouette Score 5: 0.3648120435921377
# Silhouette Score 6: 0.09683526474263016
# Silhouette Score 7: 0.08946066288945068
# Silhouette Score 8: 0.07286981627469807
# Silhouette Score 9: 0.09243698769852457

# %% [markdown]
# From the silhouette_score, will go for k value 3 which is the local maxima.

# %%
# getting the clusters with k = 5
KMeans_algo = KMeans(featuresCol='standardized', k=3)
KMeans_fit = KMeans_algo.fit(data_scale_output)
clustered_by_kmeans = KMeans_fit.transform(data_scale_output)
evaluator.evaluate(clustered_by_kmeans)
# Out:
# 0.47238578787351637

# %%
output.toPandas()
# Out:
#       age  db_wbc  basophils_abs  eosinophils_abs  lymphocytes_abs  \
# 0   52.35     4.2            NaN              NaN              NaN
# 1   55.88    19.0           0.13             0.29             5.17
# 2   46.28    20.1           0.22             0.42             5.73
# 3   80.53     6.0           0.17             1.90             6.01
# 4   81.39    36.8           0.00             0.22             1.79
# ..    ...     ...            ...              ...              ...
# 95  45.39    11.5           0.03             0.26             1.56
# 96  46.83     7.0           0.21             0.39             6.32
# 97  57.99    15.3            NaN              NaN              NaN
# 98  67.68     8.5           0.02             0.16             1.33
# 99  64.21     8.9           0.01             0.11             1.08
#
#     monocytes_abs  neutrophils_abs  basophils  eosinophils  lymphocytes  \
# 0             NaN              NaN        NaN          NaN          NaN
# 1            1.18            12.24        0.7          1.5         27.2
# 2            0.94            18.99        1.1          2.1         28.5
# 3            1.17            28.49        0.5          5.7         18.0
# 4            2.21            33.49        0.0          2.0         16.0
# ..            ...              ...        ...          ...          ...
# 95           1.17             7.60        0.3          3.0         17.4
# 96           1.64            14.35        1.0          3.0         49.0
# 97            NaN              NaN        NaN          NaN          NaN
# 98           0.50             2.75        0.4          3.4         27.9
# 99           0.92             9.08        0.1          1.0          9.5
#
#     monocytes  neutrophils  aniongap  bicarbonate   bun  calcium  chloride  \
# 0         NaN          NaN       9.0         28.0  25.0      7.8     105.0
# 1         6.2         64.4      16.0         30.0  11.0      8.9     108.0
# 2         4.7         94.5      16.0         32.0  18.0      9.1     106.0
# 3         3.5         85.3      11.0         28.0  12.0      9.3     101.0
# 4         6.0         81.0      23.0         22.0  45.0      8.7     103.0
# ..        ...          ...       ...          ...   ...      ...       ...
# 95       12.8         75.0      20.0         33.0  24.0      9.3     105.0
# 96        9.2         78.0      18.0         25.0  15.0      9.0     111.0
# 97        NaN          NaN      14.0         27.0   8.0      8.2     106.0
# 98       10.5         57.6      17.0         24.0  14.0      9.1     111.0
# 99        8.1         80.1      21.0         29.0  36.0      9.3      98.0
#
#     creatinine  glucose  sodium  potassium  inr    pt    ptt  hematocrit  \
# 0          0.3     99.0   137.0        4.5  1.5  16.6   32.3        37.6
# 1          0.7    113.0   142.0        4.2  1.2  12.6   36.6        38.1
# 2          0.9    152.0   141.0        4.0  1.0  11.3   31.8        39.1
# 3          0.8    100.0   136.0        4.4  1.5  16.0   48.4        34.1
# 4          1.6    370.0   137.0        4.8  1.7  18.9   62.5        43.0
# ..         ...      ...     ...        ...  ...   ...    ...         ...
# 95         0.9    140.0   140.0        6.2  1.7  18.9   31.8        33.6
# 96         0.9     88.0   144.0        4.7  5.7  64.4  150.0        33.3
# 97         0.7    176.0   139.0        4.1  1.7  18.7   78.3        34.4
# 98         0.9    137.0   148.0        3.5  1.1  11.7   29.2        34.2
# 99         1.5    344.0   138.0        3.8  2.8  29.6   44.6        35.0
#
#     hemoglobin   mch  mchc    mcv  platelet   rbc   rdw   wbc  scr_min  ckd  \
# 0         12.7  33.4  33.8   99.0      71.0  3.80  15.3   4.2      0.3  0.0
# 1         12.9  28.3  34.4   86.0     474.0  4.71  14.1  19.0      0.4  0.0
# 2         13.9  33.0  35.6   94.0     330.0  4.33  12.0  20.1      0.8  0.0
# 3         11.8  32.7  34.7   94.0     308.0  3.62  13.3   6.0      0.8  0.0
# 4         14.3  31.8  34.5   97.0     216.0  4.58  13.2  36.8      1.1  0.0
# ..         ...   ...   ...    ...       ...   ...   ...   ...      ...  ...
# 95        10.1  25.3  31.9   84.0     348.0  4.24  15.4  11.5      0.6  0.0
# 96        10.4  37.9  32.3  124.0     345.0  2.74  17.6   7.0      0.8  0.0
# 97        12.3  32.0  36.4   89.0     184.0  3.95  14.3  15.3      0.4  0.0
# 98        10.9  29.6  31.9   93.0     157.0  3.68  14.4   8.5      0.9  0.0
# 99        11.4  32.0  33.5  104.0     202.0  3.67  14.3   8.9      1.5  1.0
#
#     mdrd_est  scr_baseline     alt    alp     ast  bilirubin_total gender  \
# 0       0.85           0.3    88.0  103.0    98.0              1.3      F
# 1       0.84           0.4    12.0   56.0    17.0              0.4      F
# 2       0.86           0.8     NaN    NaN     NaN              NaN      F
# 3       0.78           0.8    66.0  163.0   102.0              0.2      F
# 4       1.01           1.1    44.0   99.0   210.0              0.6      M
# ..       ...           ...     ...    ...     ...              ...    ...
# 95      1.12           0.6    54.0  127.0    36.0              1.5      M
# 96      0.86           0.8    70.0  325.0   139.0              4.6      F
# 97      0.83           0.4  1343.0  125.0  1015.0              2.0      F
# 98      0.81           0.9    16.0   73.0    15.0              0.2      F
# 99      0.82           1.5     7.0  199.0    16.0              0.7      F
#
#     db_wbc_imputed  basophils_abs_imputed  eosinophils_abs_imputed  \
# 0              4.2                   0.04                     0.15
# 1             19.0                   0.13                     0.29
# 2             20.1                   0.22                     0.42
# 3              6.0                   0.17                     1.90
# 4             36.8                   0.00                     0.22
# ..             ...                    ...                      ...
# 95            11.5                   0.03                     0.26
# 96             7.0                   0.21                     0.39
# 97            15.3                   0.04                     0.15
# 98             8.5                   0.02                     0.16
# 99             8.9                   0.01                     0.11
#
#     lymphocytes_abs_imputed  monocytes_abs_imputed  neutrophils_abs_imputed  \
# 0                      1.92                   0.82                    11.70
# 1                      5.17                   1.18                    12.24
# 2                      5.73                   0.94                    18.99
# 3                      6.01                   1.17                    28.49
# 4                      1.79                   2.21                    33.49
# ..                      ...                    ...                      ...
# 95                     1.56                   1.17                     7.60
# 96                     6.32                   1.64                    14.35
# 97                     1.92                   0.82                    11.70
# 98                     1.33                   0.50                     2.75
# 99                     1.08                   0.92                     9.08
#
#     basophils_imputed  eosinophils_imputed  lymphocytes_imputed  \
# 0                 0.3                  1.0                 15.4
# 1                 0.7                  1.5                 27.2
# 2                 1.1                  2.1                 28.5
# 3                 0.5                  5.7                 18.0
# 4                 0.0                  2.0                 16.0
# ..                ...                  ...                  ...
# 95                0.3                  3.0                 17.4
# 96                1.0                  3.0                 49.0
# 97                0.3                  1.0                 15.4
# 98                0.4                  3.4                 27.9
# 99                0.1                  1.0                  9.5
#
#     monocytes_imputed  neutrophils_imputed  aniongap_imputed  \
# 0                 6.1                 81.5               9.0
# 1                 6.2                 64.4              16.0
# 2                 4.7                 94.5              16.0
# 3                 3.5                 85.3              11.0
# 4                 6.0                 81.0              23.0
# ..                ...                  ...               ...
# 95               12.8                 75.0              20.0
# 96                9.2                 78.0              18.0
# 97                6.1                 81.5              14.0
# 98               10.5                 57.6              17.0
# 99                8.1                 80.1              21.0
#
#     bicarbonate_imputed  bun_imputed  calcium_imputed  chloride_imputed  \
# 0                  28.0         25.0              7.8             105.0
# 1                  30.0         11.0              8.9             108.0
# 2                  32.0         18.0              9.1             106.0
# 3                  28.0         12.0              9.3             101.0
# 4                  22.0         45.0              8.7             103.0
# ..                  ...          ...              ...               ...
# 95                 33.0         24.0              9.3             105.0
# 96                 25.0         15.0              9.0             111.0
# 97                 27.0          8.0              8.2             106.0
# 98                 24.0         14.0              9.1             111.0
# 99                 29.0         36.0              9.3              98.0
#
#     creatinine_imputed  glucose_imputed  sodium_imputed  potassium_imputed  \
# 0                  0.3             99.0           137.0                4.5
# 1                  0.7            113.0           142.0                4.2
# 2                  0.9            152.0           141.0                4.0
# 3                  0.8            100.0           136.0                4.4
# 4                  1.6            370.0           137.0                4.8
# ..                 ...              ...             ...                ...
# 95                 0.9            140.0           140.0                6.2
# 96                 0.9             88.0           144.0                4.7
# 97                 0.7            176.0           139.0                4.1
# 98                 0.9            137.0           148.0                3.5
# 99                 1.5            344.0           138.0                3.8
#
#     inr_imputed  pt_imputed  ptt_imputed  hematocrit_imputed  \
# 0           1.5        16.6         32.3                37.6
# 1           1.2        12.6         36.6                38.1
# 2           1.0        11.3         31.8                39.1
# 3           1.5        16.0         48.4                34.1
# 4           1.7        18.9         62.5                43.0
# ..          ...         ...          ...                 ...
# 95          1.7        18.9         31.8                33.6
# 96          5.7        64.4        150.0                33.3
# 97          1.7        18.7         78.3                34.4
# 98          1.1        11.7         29.2                34.2
# 99          2.8        29.6         44.6                35.0
#
#     hemoglobin_imputed  mch_imputed  mchc_imputed  mcv_imputed  \
# 0                 12.7         33.4          33.8         99.0
# 1                 12.9         28.3          34.4         86.0
# 2                 13.9         33.0          35.6         94.0
# 3                 11.8         32.7          34.7         94.0
# 4                 14.3         31.8          34.5         97.0
# ..                 ...          ...           ...          ...
# 95                10.1         25.3          31.9         84.0
# 96                10.4         37.9          32.3        124.0
# 97                12.3         32.0          36.4         89.0
# 98                10.9         29.6          31.9         93.0
# 99                11.4         32.0          33.5        104.0
#
#     platelet_imputed  rbc_imputed  rdw_imputed  wbc_imputed  scr_min_imputed  \
# 0               71.0         3.80         15.3          4.2              0.3
# 1              474.0         4.71         14.1         19.0              0.4
# 2              330.0         4.33         12.0         20.1              0.8
# 3              308.0         3.62         13.3          6.0              0.8
# 4              216.0         4.58         13.2         36.8              1.1
# ..               ...          ...          ...          ...              ...
# 95             348.0         4.24         15.4         11.5              0.6
# 96             345.0         2.74         17.6          7.0              0.8
# 97             184.0         3.95         14.3         15.3              0.4
# 98             157.0         3.68         14.4          8.5              0.9
# 99             202.0         3.67         14.3          8.9              1.5
#
#     ckd_imputed  mdrd_est_imputed  scr_baseline_imputed  alt_imputed  \
# 0           0.0              0.85                   0.3         88.0
# 1           0.0              0.84                   0.4         12.0
# 2           0.0              0.86                   0.8         38.0
# 3           0.0              0.78                   0.8         66.0
# 4           0.0              1.01                   1.1         44.0
# ..          ...               ...                   ...          ...
# 95          0.0              1.12                   0.6         54.0
# 96          0.0              0.86                   0.8         70.0
# 97          0.0              0.83                   0.4       1343.0
# 98          0.0              0.81                   0.9         16.0
# 99          1.0              0.82                   1.5          7.0
#
#     alp_imputed  ast_imputed  bilirubin_total_imputed  gender_imputed  \
# 0         103.0         98.0                      1.3               2
# 1          56.0         17.0                      0.4               2
# 2          98.0         42.0                      0.6               2
# 3         163.0        102.0                      0.2               2
# 4          99.0        210.0                      0.6               1
# ..          ...          ...                      ...             ...
# 95        127.0         36.0                      1.5               1
# 96        325.0        139.0                      4.6               2
# 97        125.0       1015.0                      2.0               2
# 98         73.0         15.0                      0.2               2
# 99        199.0         16.0                      0.7               2
#
#                                              features  \
# 0   [4.2, 0.04, 0.15, 1.92, 0.82, 11.7, 0.3, 1.0, ...
# 1   [19.0, 0.13, 0.29, 5.17, 1.18, 12.24, 0.7, 1.5...
# 2   [20.1, 0.22, 0.42, 5.73, 0.94, 18.99, 1.1, 2.1...
# 3   [6.0, 0.17, 1.9, 6.01, 1.17, 28.49, 0.5, 5.7, ...
# 4   [36.8, 0.0, 0.22, 1.79, 2.21, 33.49, 0.0, 2.0,...
# ..                                                ...
# 95  [11.5, 0.03, 0.26, 1.56, 1.17, 7.6, 0.3, 3.0, ...
# 96  [7.0, 0.21, 0.39, 6.32, 1.64, 14.35, 1.0, 3.0,...
# 97  [15.3, 0.04, 0.15, 1.92, 0.82, 11.7, 0.3, 1.0,...
# 98  [8.5, 0.02, 0.16, 1.33, 0.5, 2.75, 0.4, 3.4, 2...
# 99  [8.9, 0.01, 0.11, 1.08, 0.92, 9.08, 0.1, 1.0, ...
#
#                                          standardized  prediction
# 0   [0.486745135530605, 0.7951951517340367, 0.5882...           8
# 1   [2.201942279781308, 2.584384243135619, 1.13725...           0
# 2   [2.3294231486107524, 4.373573334537201, 1.6470...           0
# 3   [0.6953501936151499, 3.3795793948696558, 7.451...           2
# 4   [4.264814520839586, 0.0, 0.8627488506006397, 0...           0
# ..                                                ...         ...
# 95  [1.3327545377623706, 0.5963963638005274, 1.019...           6
# 96  [0.8112418925510083, 4.174774546603692, 1.5294...           4
# 97  [1.7731429937186325, 0.7951951517340367, 0.588...           0
# 98  [0.9850794409547957, 0.3975975758670183, 0.627...           6
# 99  [1.0314361205291391, 0.19879878793350916, 0.43...           8
#
# [100 rows x 86 columns]

# %%
clustered_by_kmeans.groupby("prediction").count().toPandas()
# Out:
#    prediction  count
# 0           1     84
# 1           2      4
# 2           0     12
