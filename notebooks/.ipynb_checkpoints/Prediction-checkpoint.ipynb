# %%
import os
import sys

os.environ["PYSPARK_PYTHON"]="C:\Spark\spark-3.3.2-bin-hadoop2\python"
os.environ["JAVA_HOME"] = "C:\Program Files\Java\jdk-18.0.2.1"
os.environ["SPARK_HOME"] = "C:\Spark\spark-3.3.2-bin-hadoop2"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
sys.path.insert(0, os.environ["PYLIB"] + "/py4j-0.10.9.5-src.zip")
sys.path.insert(0, os.environ["PYLIB"] + "/pyspark.zip")

from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("r_model").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-0OH3S55:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>r_model</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
cluster_data = spark.read.option("header","true").csv("../data/EDA/clustering_data.csv")
cluster_data.printSchema()
cluster_data = cluster_data.drop("_c0")
cluster_data.printSchema()

predict_data = spark.read.option("header","true").csv("../data/EDA/prediction_value.csv")
predict_data.printSchema()
predict_data = predict_data.drop("_c0")
predict_data.printSchema()

print(cluster_data.count())
print(predict_data.count())
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- subject_id: string (nullable = true)
#  |-- hadm_id: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)
#
# root
#  |-- subject_id: string (nullable = true)
#  |-- hadm_id: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)
#
# root
#  |-- _c0: string (nullable = true)
#  |-- subject_id: string (nullable = true)
#  |-- charlson_comorbidity_index: string (nullable = true)
#
# root
#  |-- subject_id: string (nullable = true)
#  |-- charlson_comorbidity_index: string (nullable = true)
#
# 100
# 100

# %%
model_data = cluster_data.join(predict_data, cluster_data.subject_id == predict_data.subject_id, "inner")
print(model_data.count())
# Out:
# 100

# %%
model_data.printSchema()
# Out:
# root
#  |-- subject_id: string (nullable = true)
#  |-- hadm_id: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- subject_id: string (nullable = true)
#  |-- charlson_comorbidity_index: string (nullable = true)

# %%
model_data = model_data.drop("subject_id","hadm_id")
model_data.printSchema()
# Out:
# root
#  |-- age: string (nullable = true)
#  |-- db_wbc: string (nullable = true)
#  |-- basophils_abs: string (nullable = true)
#  |-- eosinophils_abs: string (nullable = true)
#  |-- lymphocytes_abs: string (nullable = true)
#  |-- monocytes_abs: string (nullable = true)
#  |-- neutrophils_abs: string (nullable = true)
#  |-- basophils: string (nullable = true)
#  |-- eosinophils: string (nullable = true)
#  |-- lymphocytes: string (nullable = true)
#  |-- monocytes: string (nullable = true)
#  |-- neutrophils: string (nullable = true)
#  |-- aniongap: string (nullable = true)
#  |-- bicarbonate: string (nullable = true)
#  |-- bun: string (nullable = true)
#  |-- calcium: string (nullable = true)
#  |-- chloride: string (nullable = true)
#  |-- creatinine: string (nullable = true)
#  |-- glucose: string (nullable = true)
#  |-- sodium: string (nullable = true)
#  |-- potassium: string (nullable = true)
#  |-- inr: string (nullable = true)
#  |-- pt: string (nullable = true)
#  |-- ptt: string (nullable = true)
#  |-- hematocrit: string (nullable = true)
#  |-- hemoglobin: string (nullable = true)
#  |-- mch: string (nullable = true)
#  |-- mchc: string (nullable = true)
#  |-- mcv: string (nullable = true)
#  |-- platelet: string (nullable = true)
#  |-- rbc: string (nullable = true)
#  |-- rdw: string (nullable = true)
#  |-- wbc: string (nullable = true)
#  |-- scr_min: string (nullable = true)
#  |-- ckd: string (nullable = true)
#  |-- mdrd_est: string (nullable = true)
#  |-- scr_baseline: string (nullable = true)
#  |-- alt: string (nullable = true)
#  |-- alp: string (nullable = true)
#  |-- ast: string (nullable = true)
#  |-- bilirubin_total: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- charlson_comorbidity_index: string (nullable = true)

# %%
# convert all values to double
import pyspark.sql.functions as F
numeric_cols = model_data.columns
numeric_cols.remove("gender")
model_data = model_data.select(*(F.round(F.col(c).cast("double"), 2).alias(c) for c in numeric_cols), "gender")
print(model_data.printSchema())
# Out:
# root
#  |-- age: double (nullable = true)
#  |-- db_wbc: double (nullable = true)
#  |-- basophils_abs: double (nullable = true)
#  |-- eosinophils_abs: double (nullable = true)
#  |-- lymphocytes_abs: double (nullable = true)
#  |-- monocytes_abs: double (nullable = true)
#  |-- neutrophils_abs: double (nullable = true)
#  |-- basophils: double (nullable = true)
#  |-- eosinophils: double (nullable = true)
#  |-- lymphocytes: double (nullable = true)
#  |-- monocytes: double (nullable = true)
#  |-- neutrophils: double (nullable = true)
#  |-- aniongap: double (nullable = true)
#  |-- bicarbonate: double (nullable = true)
#  |-- bun: double (nullable = true)
#  |-- calcium: double (nullable = true)
#  |-- chloride: double (nullable = true)
#  |-- creatinine: double (nullable = true)
#  |-- glucose: double (nullable = true)
#  |-- sodium: double (nullable = true)
#  |-- potassium: double (nullable = true)
#  |-- inr: double (nullable = true)
#  |-- pt: double (nullable = true)
#  |-- ptt: double (nullable = true)
#  |-- hematocrit: double (nullable = true)
#  |-- hemoglobin: double (nullable = true)
#  |-- mch: double (nullable = true)
#  |-- mchc: double (nullable = true)
#  |-- mcv: double (nullable = true)
#  |-- platelet: double (nullable = true)
#  |-- rbc: double (nullable = true)
#  |-- rdw: double (nullable = true)
#  |-- wbc: double (nullable = true)
#  |-- scr_min: double (nullable = true)
#  |-- ckd: double (nullable = true)
#  |-- mdrd_est: double (nullable = true)
#  |-- scr_baseline: double (nullable = true)
#  |-- alt: double (nullable = true)
#  |-- alp: double (nullable = true)
#  |-- ast: double (nullable = true)
#  |-- bilirubin_total: double (nullable = true)
#  |-- charlson_comorbidity_index: double (nullable = true)
#  |-- gender: string (nullable = true)
#
# None

# %% [markdown]
# #### Data model building

# %%
impute_numeric_cols = numeric_cols
impute_numeric_cols.remove("age")
impute_numeric_cols.remove("charlson_comorbidity_index")
print(impute_numeric_cols)

categorical_cols = ["gender"]
print(categorical_cols)
# Out:
# ['db_wbc', 'basophils_abs', 'eosinophils_abs', 'lymphocytes_abs', 'monocytes_abs', 'neutrophils_abs', 'basophils', 'eosinophils', 'lymphocytes', 'monocytes', 'neutrophils', 'aniongap', 'bicarbonate', 'bun', 'calcium', 'chloride', 'creatinine', 'glucose', 'sodium', 'potassium', 'inr', 'pt', 'ptt', 'hematocrit', 'hemoglobin', 'mch', 'mchc', 'mcv', 'platelet', 'rbc', 'rdw', 'wbc', 'scr_min', 'ckd', 'mdrd_est', 'scr_baseline', 'alt', 'alp', 'ast', 'bilirubin_total']
# ['gender']

# %%
# Feature transformation for categorical features
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
si = StringIndexer(inputCols=categorical_cols, outputCols=[c+'_idx' for c in categorical_cols], handleInvalid="keep")
ohe = OneHotEncoder(inputCols=[c+'_idx' for c in categorical_cols], outputCols=[c+'_imputed' for c in categorical_cols], handleInvalid="keep")

# %%
# fill the missing values with the median value
from pyspark.ml.feature import Imputer

imputer = Imputer(
    inputCols = impute_numeric_cols, 
    outputCols = ["{}_imputed".format(c) for c in impute_numeric_cols]
    ).setStrategy("median")

# %%
cluster_cols = [c+'_imputed' for c in categorical_cols]
cluster_cols.extend(["{}_imputed".format(c) for c in impute_numeric_cols])
cluster_cols.append("age")
assembler = VectorAssembler( inputCols = cluster_cols, outputCol = 'features')

# %%
from pyspark.ml.feature import StandardScaler
scaler = StandardScaler( inputCol = 'features', outputCol = 'standardized')

# %%
from pyspark.ml import Pipeline

pipeline =  Pipeline(stages = [si, ohe, imputer, assembler, scaler])
data_model = pipeline.fit(model_data)

# %%
# save data model
data_model.write().overwrite().save("../model/data_model.pkl")

# %% [markdown]
# #### Prediction model

# %%
# Splitting the data into train and test (Remember you are expected to compare the model later)
train, test = model_data.randomSplit([0.7,0.3])
print("Size of training data {0}".format(train.count()))
print("Size of test data {0}".format(test.count()))
# Out:
# Size of training data 70
# Size of test data 30

# %%
# model train
from pyspark.ml.regression import LinearRegression
lr = LinearRegression( featuresCol="standardized", labelCol="charlson_comorbidity_index")

model_input = data_model.transform(train)
model = lr.fit(model_input)

# save model
model.write().overwrite().save("gender_predict_model.pkl")

# %% [markdown]
# #### model evaluation

# %%
predictionoutput = model.transform(model_input)
predictionoutput.toPandas()
# Out:
#       age  db_wbc  basophils_abs  eosinophils_abs  lymphocytes_abs  \
# 0   21.16    22.7            NaN              NaN              NaN
# 1   28.32    19.2            NaN              NaN              NaN
# 2   28.99    13.0           0.02             0.13             1.55
# 3   34.82    16.2            NaN              NaN              NaN
# 4   38.13    44.3           0.13             0.13             3.54
# ..    ...     ...            ...              ...              ...
# 65  86.44    41.1           0.09             0.03             2.11
# 66  87.20    12.4           0.02             0.11             0.94
# 67  87.87    10.0           0.02             0.16             0.43
# 68  88.50    13.6           0.03             0.04             1.33
# 69  91.12    20.6           0.04             0.02             1.55
#
#     monocytes_abs  neutrophils_abs  basophils  eosinophils  lymphocytes  \
# 0             NaN              NaN        NaN          NaN          NaN
# 1             NaN              NaN        NaN          NaN          NaN
# 2            0.81             6.43        0.2          1.4         17.2
# 3             NaN              NaN        NaN          NaN          NaN
# 4            1.28            40.80        0.3          0.3          8.0
# ..            ...              ...        ...          ...          ...
# 65           1.43            38.09        0.2          0.1          9.9
# 66           0.42            10.89        0.2          0.9          7.6
# 67           0.41             5.46        0.3          2.5          6.6
# 68           0.49            11.70        0.2          0.3          9.8
# 69           0.49            18.83        0.2          0.1          7.5
#
#     monocytes  neutrophils  aniongap  bicarbonate   bun  calcium  chloride  \
# 0         NaN          NaN      19.0         29.0  14.0      9.0     108.0
# 1         NaN          NaN      15.0         34.0  17.0      8.7     108.0
# 2         9.0         71.3      14.0         26.0  11.0      8.7     111.0
# 3         NaN          NaN      21.0         25.0  15.0      9.0     108.0
# 4         2.9         92.1      19.0         30.0  21.0     12.1     108.0
# ..        ...          ...       ...          ...   ...      ...       ...
# 65        4.2         92.6      17.0         26.0  17.0      8.5     107.0
# 66        3.4         87.8      19.0         31.0  32.0      8.9     111.0
# 67        6.3         98.0      22.0         30.0  69.0      9.3      92.0
# 68        3.6         86.0      12.0         25.0  28.0      8.3     112.0
# 69        2.4         91.4      18.0         26.0  33.0      9.4     136.0
#
#     creatinine  glucose  sodium  potassium  inr    pt   ptt  hematocrit  \
# 0          0.7    140.0   140.0        4.3  1.5  16.1  41.2        33.2
# 1          1.1    116.0   140.0        4.5  1.7  18.7  29.6        38.1
# 2          0.7    162.0   142.0        4.1  1.2  12.7  28.9        32.4
# 3          1.1    151.0   141.0        4.9  1.0  10.9  24.3        43.8
# 4          0.9    266.0   140.0        5.2  1.4  15.8  31.5        34.7
# ..         ...      ...     ...        ...  ...   ...   ...         ...
# 65         0.7    225.0   138.0        4.0  2.1  22.7  29.7        37.6
# 66         1.5    175.0   149.0        5.0  1.0  10.9  25.7        38.0
# 67         4.0    188.0   130.0        5.6  3.4  38.5  96.9        37.1
# 68         0.8    175.0   141.0        4.0  1.3  13.7  27.4        39.3
# 69         0.8    352.0   168.0        4.6  1.8  19.8  34.8        37.1
#
#     hemoglobin   mch  mchc    mcv  platelet   rbc   rdw   wbc  scr_min  ckd  \
# 0         11.4  30.8  34.5   90.0     229.0  3.77  12.5  22.7      0.5  0.0
# 1         13.5  30.3  36.7   85.0     242.0  4.70  12.9  19.2      0.8  0.0
# 2         10.1  28.5  31.9   92.0     312.0  3.55  14.2  13.0      0.3  0.0
# 3         14.9  32.3  34.0   97.0     306.0  4.61  13.8  16.2      0.9  0.0
# 4         12.0  26.6  37.1   77.0     588.0  4.68  17.4  44.3      0.6  0.0
# ..         ...   ...   ...    ...       ...   ...   ...   ...      ...  ...
# 65        12.6  32.8  33.7   99.0     214.0  3.85  14.1  41.1      0.6  0.0
# 66        11.8  33.4  33.6  104.0     244.0  3.68  15.8  12.4      1.2  1.0
# 67        12.7  33.9  36.3   97.0     156.0  3.85  14.3  10.0      2.0  1.0
# 68        10.1  30.3  35.0   90.0     199.0  3.40  16.6  13.6      0.7  0.0
# 69        11.6  28.3  33.0   89.0     407.0  4.15  16.1  20.6      0.4  0.0
#
#     mdrd_est  scr_baseline   alt    alp   ast  bilirubin_total  \
# 0       0.99           0.5   NaN    NaN   NaN              NaN
# 1       1.22           0.8   NaN    NaN   NaN              NaN
# 2       0.94           0.3   NaN    NaN   NaN              NaN
# 3       1.18           0.9   NaN    NaN   NaN              NaN
# 4       0.89           0.6  19.0  180.0  66.0              0.4
# ..       ...           ...   ...    ...   ...              ...
# 65      0.77           0.6  17.0   56.0  11.0              0.9
# 66      1.00           1.2  28.0   79.0  29.0              0.9
# 67      1.00           2.0   7.0   49.0  12.0              0.3
# 68      0.77           0.7   NaN    NaN   NaN              NaN
# 69      0.77           0.4  24.0  103.0  19.0              0.2
#
#     charlson_comorbidity_index gender  gender_idx   gender_imputed  \
# 0                          0.0      F         1.0  (0.0, 1.0, 0.0)
# 1                          0.0      M         0.0  (1.0, 0.0, 0.0)
# 2                          1.0      F         1.0  (0.0, 1.0, 0.0)
# 3                          0.0      M         0.0  (1.0, 0.0, 0.0)
# 4                          8.0      F         1.0  (0.0, 1.0, 0.0)
# ..                         ...    ...         ...              ...
# 65                         6.0      F         1.0  (0.0, 1.0, 0.0)
# 66                         9.0      M         0.0  (1.0, 0.0, 0.0)
# 67                        11.0      M         0.0  (1.0, 0.0, 0.0)
# 68                         6.0      F         1.0  (0.0, 1.0, 0.0)
# 69                         8.0      F         1.0  (0.0, 1.0, 0.0)
#
#     db_wbc_imputed  basophils_abs_imputed  eosinophils_abs_imputed  \
# 0             22.7                   0.04                     0.15
# 1             19.2                   0.04                     0.15
# 2             13.0                   0.02                     0.13
# 3             16.2                   0.04                     0.15
# 4             44.3                   0.13                     0.13
# ..             ...                    ...                      ...
# 65            41.1                   0.09                     0.03
# 66            12.4                   0.02                     0.11
# 67            10.0                   0.02                     0.16
# 68            13.6                   0.03                     0.04
# 69            20.6                   0.04                     0.02
#
#     lymphocytes_abs_imputed  monocytes_abs_imputed  neutrophils_abs_imputed  \
# 0                      1.92                   0.82                    11.70
# 1                      1.92                   0.82                    11.70
# 2                      1.55                   0.81                     6.43
# 3                      1.92                   0.82                    11.70
# 4                      3.54                   1.28                    40.80
# ..                      ...                    ...                      ...
# 65                     2.11                   1.43                    38.09
# 66                     0.94                   0.42                    10.89
# 67                     0.43                   0.41                     5.46
# 68                     1.33                   0.49                    11.70
# 69                     1.55                   0.49                    18.83
#
#     basophils_imputed  eosinophils_imputed  lymphocytes_imputed  \
# 0                 0.3                  1.0                 15.4
# 1                 0.3                  1.0                 15.4
# 2                 0.2                  1.4                 17.2
# 3                 0.3                  1.0                 15.4
# 4                 0.3                  0.3                  8.0
# ..                ...                  ...                  ...
# 65                0.2                  0.1                  9.9
# 66                0.2                  0.9                  7.6
# 67                0.3                  2.5                  6.6
# 68                0.2                  0.3                  9.8
# 69                0.2                  0.1                  7.5
#
#     monocytes_imputed  neutrophils_imputed  aniongap_imputed  \
# 0                 6.1                 81.5              19.0
# 1                 6.1                 81.5              15.0
# 2                 9.0                 71.3              14.0
# 3                 6.1                 81.5              21.0
# 4                 2.9                 92.1              19.0
# ..                ...                  ...               ...
# 65                4.2                 92.6              17.0
# 66                3.4                 87.8              19.0
# 67                6.3                 98.0              22.0
# 68                3.6                 86.0              12.0
# 69                2.4                 91.4              18.0
#
#     bicarbonate_imputed  bun_imputed  calcium_imputed  chloride_imputed  \
# 0                  29.0         14.0              9.0             108.0
# 1                  34.0         17.0              8.7             108.0
# 2                  26.0         11.0              8.7             111.0
# 3                  25.0         15.0              9.0             108.0
# 4                  30.0         21.0             12.1             108.0
# ..                  ...          ...              ...               ...
# 65                 26.0         17.0              8.5             107.0
# 66                 31.0         32.0              8.9             111.0
# 67                 30.0         69.0              9.3              92.0
# 68                 25.0         28.0              8.3             112.0
# 69                 26.0         33.0              9.4             136.0
#
#     creatinine_imputed  glucose_imputed  sodium_imputed  potassium_imputed  \
# 0                  0.7            140.0           140.0                4.3
# 1                  1.1            116.0           140.0                4.5
# 2                  0.7            162.0           142.0                4.1
# 3                  1.1            151.0           141.0                4.9
# 4                  0.9            266.0           140.0                5.2
# ..                 ...              ...             ...                ...
# 65                 0.7            225.0           138.0                4.0
# 66                 1.5            175.0           149.0                5.0
# 67                 4.0            188.0           130.0                5.6
# 68                 0.8            175.0           141.0                4.0
# 69                 0.8            352.0           168.0                4.6
#
#     inr_imputed  pt_imputed  ptt_imputed  hematocrit_imputed  \
# 0           1.5        16.1         41.2                33.2
# 1           1.7        18.7         29.6                38.1
# 2           1.2        12.7         28.9                32.4
# 3           1.0        10.9         24.3                43.8
# 4           1.4        15.8         31.5                34.7
# ..          ...         ...          ...                 ...
# 65          2.1        22.7         29.7                37.6
# 66          1.0        10.9         25.7                38.0
# 67          3.4        38.5         96.9                37.1
# 68          1.3        13.7         27.4                39.3
# 69          1.8        19.8         34.8                37.1
#
#     hemoglobin_imputed  mch_imputed  mchc_imputed  mcv_imputed  \
# 0                 11.4         30.8          34.5         90.0
# 1                 13.5         30.3          36.7         85.0
# 2                 10.1         28.5          31.9         92.0
# 3                 14.9         32.3          34.0         97.0
# 4                 12.0         26.6          37.1         77.0
# ..                 ...          ...           ...          ...
# 65                12.6         32.8          33.7         99.0
# 66                11.8         33.4          33.6        104.0
# 67                12.7         33.9          36.3         97.0
# 68                10.1         30.3          35.0         90.0
# 69                11.6         28.3          33.0         89.0
#
#     platelet_imputed  rbc_imputed  rdw_imputed  wbc_imputed  scr_min_imputed  \
# 0              229.0         3.77         12.5         22.7              0.5
# 1              242.0         4.70         12.9         19.2              0.8
# 2              312.0         3.55         14.2         13.0              0.3
# 3              306.0         4.61         13.8         16.2              0.9
# 4              588.0         4.68         17.4         44.3              0.6
# ..               ...          ...          ...          ...              ...
# 65             214.0         3.85         14.1         41.1              0.6
# 66             244.0         3.68         15.8         12.4              1.2
# 67             156.0         3.85         14.3         10.0              2.0
# 68             199.0         3.40         16.6         13.6              0.7
# 69             407.0         4.15         16.1         20.6              0.4
#
#     ckd_imputed  mdrd_est_imputed  scr_baseline_imputed  alt_imputed  \
# 0           0.0              0.99                   0.5         38.0
# 1           0.0              1.22                   0.8         38.0
# 2           0.0              0.94                   0.3         38.0
# 3           0.0              1.18                   0.9         38.0
# 4           0.0              0.89                   0.6         19.0
# ..          ...               ...                   ...          ...
# 65          0.0              0.77                   0.6         17.0
# 66          1.0              1.00                   1.2         28.0
# 67          1.0              1.00                   2.0          7.0
# 68          0.0              0.77                   0.7         38.0
# 69          0.0              0.77                   0.4         24.0
#
#     alp_imputed  ast_imputed  bilirubin_total_imputed  \
# 0          98.0         42.0                      0.6
# 1          98.0         42.0                      0.6
# 2          98.0         42.0                      0.6
# 3          98.0         42.0                      0.6
# 4         180.0         66.0                      0.4
# ..          ...          ...                      ...
# 65         56.0         11.0                      0.9
# 66         79.0         29.0                      0.9
# 67         49.0         12.0                      0.3
# 68         98.0         42.0                      0.6
# 69        103.0         19.0                      0.2
#
#                                              features  \
# 0   [0.0, 1.0, 0.0, 22.7, 0.04, 0.15, 1.92, 0.82, ...
# 1   [1.0, 0.0, 0.0, 19.2, 0.04, 0.15, 1.92, 0.82, ...
# 2   [0.0, 1.0, 0.0, 13.0, 0.02, 0.13, 1.55, 0.81, ...
# 3   [1.0, 0.0, 0.0, 16.2, 0.04, 0.15, 1.92, 0.82, ...
# 4   [0.0, 1.0, 0.0, 44.3, 0.13, 0.13, 3.54, 1.28, ...
# ..                                                ...
# 65  [0.0, 1.0, 0.0, 41.1, 0.09, 0.03, 2.11, 1.43, ...
# 66  [1.0, 0.0, 0.0, 12.4, 0.02, 0.11, 0.94, 0.42, ...
# 67  [1.0, 0.0, 0.0, 10.0, 0.02, 0.16, 0.43, 0.41, ...
# 68  [0.0, 1.0, 0.0, 13.6, 0.03, 0.04, 1.33, 0.49, ...
# 69  [0.0, 1.0, 0.0, 20.6, 0.04, 0.02, 1.55, 0.49, ...
#
#                                          standardized  prediction
# 0   [0.0, 2.0097680678771135, 0.0, 2.6307415658439...   -0.095455
# 1   [2.0097680678771135, 0.0, 0.0, 2.2251206195684...   -0.605423
# 2   [0.0, 2.0097680678771135, 0.0, 1.5065920861661...    0.996913
# 3   [2.0097680678771135, 0.0, 0.0, 1.8774455227609...   -0.330327
# 4   [0.0, 2.0097680678771135, 0.0, 5.1340022628585...    7.614551
# ..                                                ...         ...
# 65  [0.0, 2.0097680678771135, 0.0, 4.7631488262637...    6.697023
# 66  [2.0097680678771135, 0.0, 0.0, 1.4370570668046...   10.418663
# 67  [2.0097680678771135, 0.0, 0.0, 1.1589169893585...   11.102335
# 68  [0.0, 2.0097680678771135, 0.0, 1.5761271055276...    7.054593
# 69  [0.0, 2.0097680678771135, 0.0, 2.3873689980786...    8.044445
#
# [70 rows x 88 columns]

# %%
predictionoutput.select("charlson_comorbidity_index", "prediction").toPandas()
# Out:
#     charlson_comorbidity_index  prediction
# 0                          0.0   -0.095455
# 1                          0.0   -0.605423
# 2                          1.0    0.996913
# 3                          0.0   -0.330327
# 4                          8.0    7.614551
# ..                         ...         ...
# 65                         6.0    6.697023
# 66                         9.0   10.418663
# 67                        11.0   11.102335
# 68                         6.0    7.054593
# 69                         8.0    8.044445
#
# [70 rows x 2 columns]

# %%
# evaluate with test data

model_input_test = data_model.transform(test)

pred_results = model.evaluate(model_input_test)
pred_results.predictions.select("charlson_comorbidity_index", "prediction").toPandas()
# Out:
#     charlson_comorbidity_index  prediction
# 0                          0.0    4.071111
# 1                          1.0   -0.220343
# 2                          1.0    1.109475
# 3                          0.0    2.022955
# 4                          0.0    2.104261
# 5                          1.0   -0.880771
# 6                          7.0    5.134867
# 7                          3.0    7.445351
# 8                          6.0    4.011817
# 9                          7.0    2.076385
# 10                         3.0    3.734106
# 11                         1.0    3.286668
# 12                         5.0    3.669876
# 13                         3.0    4.669566
# 14                         8.0   13.453625
# 15                         2.0    7.290494
# 16                         5.0    8.426734
# 17                        10.0    4.746734
# 18                         3.0    6.077725
# 19                         5.0    4.706851
# 20                        10.0    6.483783
# 21                         4.0   -2.730113
# 22                         5.0    7.054073
# 23                         6.0    5.986233
# 24                         4.0   -6.135227
# 25                         4.0    6.136981
# 26                         5.0    5.786784
# 27                         9.0   16.468696
# 28                         9.0   12.875844
# 29                         6.0   13.561850

# %% [markdown]
# #### model from hyperparameter tuning

# %%
# We use a ParamGridBuilder to construct a grid of parameters to search over.
# TrainValidationSplit will try all combinations of values and determine best model using
# the evaluator.
from pyspark.ml.regression import LinearRegression
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit
from  pyspark.ml.evaluation import RegressionEvaluator
lr2 = LinearRegression( featuresCol="standardized", labelCol="charlson_comorbidity_index")
paramGrid = ParamGridBuilder()\
    .baseOn({lr2.labelCol: 'charlson_comorbidity_index'}) \
    .baseOn([lr2.predictionCol, 'prediction']) \
    .addGrid(lr2.regParam, [0.1, 0.01]) \
    .addGrid(lr2.fitIntercept, [False, True])\
    .addGrid(lr2.elasticNetParam, [0.0, 0.5, 1.0])\
    .build()



# In this case the estimator is simply the linear regression.
# A TrainValidationSplit requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
eva = RegressionEvaluator()
eva.setLabelCol("charlson_comorbidity_index")
tvs = TrainValidationSplit(estimator=lr2,
                           estimatorParamMaps=paramGrid,
                           evaluator=eva,
                           # 80% of the data will be used for training, 20% for validation.
                           trainRatio=0.8)

# Run TrainValidationSplit, and choose the best set of parameters.
model_input = data_model.transform(train)
model = tvs.fit(model_input)

# %%
predictionoutput = model.transform(model_input)
predictionoutput.select("charlson_comorbidity_index", "prediction").toPandas()
# Out:
#     charlson_comorbidity_index  prediction
# 0                          0.0   -0.278063
# 1                          0.0   -0.463937
# 2                          1.0    0.437665
# 3                          0.0    0.354605
# 4                          8.0    4.287824
# ..                         ...         ...
# 65                         6.0    8.125953
# 66                         9.0    8.791808
# 67                        11.0   10.956871
# 68                         6.0    6.807137
# 69                         8.0    7.366391
#
# [70 rows x 2 columns]

# %%
model_input_test = data_model.transform(test)

pred_results = model.transform(model_input_test)
pred_results.select("charlson_comorbidity_index", "prediction").toPandas()
# Out:
#     charlson_comorbidity_index  prediction
# 0                          0.0    0.997203
# 1                          1.0   -0.023460
# 2                          1.0    0.511531
# 3                          0.0    1.718500
# 4                          0.0    0.210312
# 5                          1.0    1.559048
# 6                          7.0    3.507339
# 7                          3.0    4.599202
# 8                          6.0    3.458138
# 9                          7.0    2.894969
# 10                         3.0    4.771119
# 11                         1.0    3.288431
# 12                         5.0    5.895734
# 13                         3.0    3.453783
# 14                         8.0    9.625324
# 15                         2.0    4.645269
# 16                         5.0   13.419462
# 17                        10.0    3.700142
# 18                         3.0    5.053808
# 19                         5.0    4.020208
# 20                        10.0    5.192854
# 21                         4.0    2.731508
# 22                         5.0    6.135493
# 23                         6.0    7.144634
# 24                         4.0    4.118990
# 25                         4.0    6.058471
# 26                         5.0    5.978359
# 27                         9.0   17.600600
# 28                         9.0   11.432316
# 29                         6.0   15.503830

# %%
model.validationMetrics
# Out:
# [3.1092072111442883,
#  1.9258067116723825,
#  1.942399718861156,
#  2.8156283051201556,
#  2.3981293741552654,
#  2.31292771292195,
#  5.66437900154209,
#  1.9851843645382086,
#  2.004441122773904,
#  5.069654194027419,
#  3.435606089231164,
#  3.0210319354417994]

# %%
params = [{p.name: v for p, v in m.items()} for m in model.getEstimatorParamMaps()]

pd.DataFrame.from_dict([
    {model.getEvaluator().getMetricName(): metric, **ps} 
    for ps, metric in zip(params, model.validationMetrics)
])
# Out:
#         rmse                    labelCol predictionCol  regParam  \
# 0   3.109207  charlson_comorbidity_index    prediction      0.10
# 1   1.925807  charlson_comorbidity_index    prediction      0.10
# 2   1.942400  charlson_comorbidity_index    prediction      0.10
# 3   2.815628  charlson_comorbidity_index    prediction      0.10
# 4   2.398129  charlson_comorbidity_index    prediction      0.10
# 5   2.312928  charlson_comorbidity_index    prediction      0.10
# 6   5.664379  charlson_comorbidity_index    prediction      0.01
# 7   1.985184  charlson_comorbidity_index    prediction      0.01
# 8   2.004441  charlson_comorbidity_index    prediction      0.01
# 9   5.069654  charlson_comorbidity_index    prediction      0.01
# 10  3.435606  charlson_comorbidity_index    prediction      0.01
# 11  3.021032  charlson_comorbidity_index    prediction      0.01
#
#     fitIntercept  elasticNetParam
# 0          False              0.0
# 1          False              0.5
# 2          False              1.0
# 3           True              0.0
# 4           True              0.5
# 5           True              1.0
# 6          False              0.0
# 7          False              0.5
# 8          False              1.0
# 9           True              0.0
# 10          True              0.5
# 11          True              1.0

# %%
model.bestModel.extractParamMap()
# Out:
# {Param(parent='LinearRegression_0be2bc503e97', name='aggregationDepth', doc='suggested depth for treeAggregate (>= 2).'): 2,
#  Param(parent='LinearRegression_0be2bc503e97', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.5,
#  Param(parent='LinearRegression_0be2bc503e97', name='epsilon', doc='The shape parameter to control the amount of robustness. Must be > 1.0. Only valid when loss is huber'): 1.35,
#  Param(parent='LinearRegression_0be2bc503e97', name='featuresCol', doc='features column name.'): 'standardized',
#  Param(parent='LinearRegression_0be2bc503e97', name='fitIntercept', doc='whether to fit an intercept term.'): False,
#  Param(parent='LinearRegression_0be2bc503e97', name='labelCol', doc='label column name.'): 'charlson_comorbidity_index',
#  Param(parent='LinearRegression_0be2bc503e97', name='loss', doc='The loss function to be optimized. Supported options: squaredError, huber.'): 'squaredError',
#  Param(parent='LinearRegression_0be2bc503e97', name='maxBlockSizeInMB', doc='maximum memory in MB for stacking input data into blocks. Data is stacked within partitions. If more than remaining data size in a partition then it is adjusted to the data size. Default 0.0 represents choosing optimal value, depends on specific algorithm. Must be >= 0.'): 0.0,
#  Param(parent='LinearRegression_0be2bc503e97', name='maxIter', doc='max number of iterations (>= 0).'): 100,
#  Param(parent='LinearRegression_0be2bc503e97', name='predictionCol', doc='prediction column name.'): 'prediction',
#  Param(parent='LinearRegression_0be2bc503e97', name='regParam', doc='regularization parameter (>= 0).'): 0.1,
#  Param(parent='LinearRegression_0be2bc503e97', name='solver', doc='The solver algorithm for optimization. Supported options: auto, normal, l-bfgs.'): 'auto',
#  Param(parent='LinearRegression_0be2bc503e97', name='standardization', doc='whether to standardize the training features before fitting the model.'): True,
#  Param(parent='LinearRegression_0be2bc503e97', name='tol', doc='the convergence tolerance for iterative algorithms (>= 0).'): 1e-06}

# %%
bm = model.bestModel
model_input_test = data_model.transform(test)

pred_results = bm.evaluate(model_input_test)
print(pred_results.meanSquaredError)
print(pred_results.r2)
print(pred_results.rootMeanSquaredError)
print(pred_results.r2adj)
# Out:
# 12.70563216752971
# 0.5510377325961233
# 3.5644960608099585
# 1.9620620015797359

# %%
bm = model.bestModel
model_input_train = data_model.transform(train)

pred_results = bm.evaluate(model_input_train)
print(pred_results.meanSquaredError)
print(pred_results.r2)
print(pred_results.rootMeanSquaredError)
print(pred_results.r2adj)
# Out:
# 2.230848964888361
# 0.9230741736245393
# 1.4936026797272295
# 0.7928920059122211

# %%
pred_results.residuals.toPandas()
# Out:
#     residuals
# 0    0.278063
# 1    0.463937
# 2    0.562335
# 3   -0.354605
# 4    3.712176
# ..        ...
# 65  -2.125953
# 66   0.208192
# 67   0.043129
# 68  -0.807137
# 69   0.633609
#
# [70 rows x 1 columns]
